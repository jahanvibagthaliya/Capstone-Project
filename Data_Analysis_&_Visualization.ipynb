# %% [markdown]
# # Data Analysis & Data Visualization for DMart Product and Sales Dataset

# %%
import pandas as pd

# %%
dataset = pd.read_csv(r"C:\Users\Vaishnav\Downloads\ML_Project\Clean Dmart sales data.csv")
dataset.head(5)
# Out:
#   Customer ID Product ID   Order ID  Customer Age  Gender  \
# 0       YSB75      BW653  479577309            28  Female
# 1       FUS93      XV061  634865221            47    Male
# 2       AJP28      GF695  113166210            63  Female
# 3       URC55      VM478  740539230            41    Male
# 4       ZOP23      XD230  156544145            22  Female
#
#                             Product Name      MRP  Discount Price  Category  \
# 0  Ariel Matic Top Load Liquid Detergent   977.44          909.02  Imported
# 1                         VSR Channa Dal   834.09          450.41   Branded
# 2          Tenali Double Horse Chana Dal  1095.20         1007.58   Branded
# 3                               Tata Tea   748.16          389.04  Imported
# 4                         VSR Channa Dal  1249.04          911.80     Local
#
#             State  ... Delivery Date Cancellation Date  Payment Method  \
# 0  Andhra Pradesh  ...    13-05-2022               NaN          Credit
# ...

# %%
dataset.describe()
# Out:
#            Order ID  Customer Age           MRP  Discount Price  \
# count  2.499200e+04  24992.000000  24992.000000    24992.000000
# mean   4.986928e+08     43.854754   1013.751282      735.650378
# std    2.881905e+08     15.286399    571.020253      441.348028
# min    1.912800e+04     18.000000     20.040000       10.910000
# 25%    2.502974e+08     31.000000    524.042500      367.687500
# 50%    4.997311e+08     44.000000   1014.415000      713.140000
# 75%    7.470629e+08     57.000000   1506.775000     1061.347500
# max    9.999131e+08     70.000000   1999.920000     1876.220000
#
#        Time Spent on Website        Rating       Pin Code  No of Clicks  \
# count           24992.000000  24992.000000   24992.000000  24992.000000
# mean               10.152534      3.008683  496694.463948     50.420054
# std                10.967104      1.159489  287736.503530     28.867779
# min                 1.000000      1.000000       5.000000      1.000000
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24992 entries, 0 to 24991
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Customer ID              24992 non-null  object
#  1   Product ID               24992 non-null  object
#  2   Order ID                 24992 non-null  int64
#  3   Customer Age             24992 non-null  int64
#  4   Gender                   24992 non-null  object
#  5   Product Name             24992 non-null  object
#  6   MRP                      24992 non-null  float64
#  7   Discount Price           24992 non-null  float64
#  8   Category                 24992 non-null  object
#  9   State                    24992 non-null  object
#  10  City                     24992 non-null  object
#  11  Subscription             24992 non-null  object
#  12  Time Spent on Website    24992 non-null  float64
#  13  Rating                   24992 non-null  float64
# ...

# %%
dataset.drop(columns=['Cancellation Date'],inplace=True)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24992 entries, 0 to 24991
# Data columns (total 27 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Customer ID              24992 non-null  object
#  1   Product ID               24992 non-null  object
#  2   Order ID                 24992 non-null  int64
#  3   Customer Age             24992 non-null  int64
#  4   Gender                   24992 non-null  object
#  5   Product Name             24992 non-null  object
#  6   MRP                      24992 non-null  float64
#  7   Discount Price           24992 non-null  float64
#  8   Category                 24992 non-null  object
#  9   State                    24992 non-null  object
#  10  City                     24992 non-null  object
#  11  Subscription             24992 non-null  object
#  12  Time Spent on Website    24992 non-null  float64
#  13  Rating                   24992 non-null  float64
# ...

# %% [markdown]
# # 1. Top 5 Profitable Product Name

# %%
dataset['Total Order Value'] = pd.to_numeric(dataset['Total Order Value'],errors='coerce')

# %%
dataset['Total Order Value'].dtype
# Out:
# dtype('float64')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24992 entries, 0 to 24991
# Data columns (total 27 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Customer ID              24992 non-null  object
#  1   Product ID               24992 non-null  object
#  2   Order ID                 24992 non-null  int64
#  3   Customer Age             24992 non-null  int64
#  4   Gender                   24992 non-null  object
#  5   Product Name             24992 non-null  object
#  6   MRP                      24992 non-null  float64
#  7   Discount Price           24992 non-null  float64
#  8   Category                 24992 non-null  object
#  9   State                    24992 non-null  object
#  10  City                     24992 non-null  object
#  11  Subscription             24992 non-null  object
#  12  Time Spent on Website    24992 non-null  float64
#  13  Rating                   24992 non-null  float64
# ...

# %%
dataset['Total Order Value']=dataset['Total Order Value'].fillna(0)   # Fill NA with 0

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24992 entries, 0 to 24991
# Data columns (total 27 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Customer ID              24992 non-null  object
#  1   Product ID               24992 non-null  object
#  2   Order ID                 24992 non-null  int64
#  3   Customer Age             24992 non-null  int64
#  4   Gender                   24992 non-null  object
#  5   Product Name             24992 non-null  object
#  6   MRP                      24992 non-null  float64
#  7   Discount Price           24992 non-null  float64
#  8   Category                 24992 non-null  object
#  9   State                    24992 non-null  object
#  10  City                     24992 non-null  object
#  11  Subscription             24992 non-null  object
#  12  Time Spent on Website    24992 non-null  float64
#  13  Rating                   24992 non-null  float64
# ...

# %% [markdown]
# - Now our dataset is clean and there is no null value presentation in our dataset

# %%
dataset['Profit'] = dataset['MRP'] - dataset['Discount Price']

# %%
top_product = dataset.groupby('Product Name')['Profit'].sum().reset_index()
top_product
# Out:
#                                   Product Name     Profit
# 0                         Amul Butter Unsalted  300734.77
# 1                        Amul Taaza Toned Milk  303512.24
# 2      Ariel Matic Front Load Liquid Detergent  327072.53
# 3        Ariel Matic Top Load Liquid Detergent  314601.82
# 4                  Cavin's Chocolate Milkshake  332426.86
# 5             Harpic Bathroom Cleaner - Floral  341270.71
# 6                        Kellogg's Corn Flakes  311921.35
# 7   Nimyle Herbal Anti-Bacterial Floor Cleaner  308024.43
# 8                Nutri Delite Breakfast Cereal  323011.95
# 9          Parle Nutricrunch Digestive Cookies  342136.53
# 10  Pigeon Induction Cooktop Acer Plus: 1800 W  314502.18
# 11          Premia Tur Dal Latur (Kandi Pappu)  303937.52
# 12                    Sofit Soya Drink Vanilla  301025.72
# 13         Sunfeast Dark Fantasy Yumfills Cake  309890.95
# 14                      Tata Sampann Chana Dal  300649.52
# ...

# %% [markdown]
# - Above table shows Profit of different Product Name

# %%
top_5_profitable_product = top_product.sort_values(by='Profit',ascending=False)
top_5_profitable_product.head(5)
# Out:
#                                Product Name     Profit
# 9       Parle Nutricrunch Digestive Cookies  342136.53
# 5          Harpic Bathroom Cleaner - Floral  341270.71
# 4               Cavin's Chocolate Milkshake  332426.86
# 19  Usha Heavy Weight Iron - El3710: 1000 W  332134.14
# 2   Ariel Matic Front Load Liquid Detergent  327072.53

# %% [markdown]
# - Above table shows list of Top 5 Profitable Product Names

# %% [markdown]
# # 2. Visual Representation of Top 5 Profitable Product using Bar Chart

# %%
import matplotlib.pyplot as plt

# %%
top_5_profitable_product = top_5_profitable_product.head(5)

# %%
plt.figure(figsize=(20,8))
plt.bar(top_5_profitable_product['Product Name'],top_5_profitable_product['Profit'],color = 'olive')
plt.xlabel("Product Name")
plt.ylabel("Profit")
plt.title("Top 5 Product by Profit")
plt.show()

# %% [markdown]
# # 3. Unit sold by Product name

# %%
dataset['Estimated Units Sold'] = (dataset['Total Order Value']/dataset['Discount Price']).round().astype(int)

# %%
dataset['Estimated Units Sold'].dtype
# Out:
# dtype('int32')

# %%
Product_unit_sold = dataset.groupby('Product Name')['Estimated Units Sold'].sum().reset_index()

# %%
Product_unit_sold = Product_unit_sold.sort_values(by='Estimated Units Sold' ,ascending=False)
Product_unit_sold
# Out:
#                                   Product Name  Estimated Units Sold
# 9          Parle Nutricrunch Digestive Cookies                  1166
# 21                       Wagh Bakri Masala Tea                  1153
# 5             Harpic Bathroom Cleaner - Floral                  1153
# 15       Tata Sampann Moong Dal (Pesara Pappu)                  1126
# 8                Nutri Delite Breakfast Cereal                  1124
# 4                  Cavin's Chocolate Milkshake                  1110
# 7   Nimyle Herbal Anti-Bacterial Floor Cleaner                  1106
# 10  Pigeon Induction Cooktop Acer Plus: 1800 W                  1088
# 17            Tata Tea Chakra Gold Premium Tea                  1083
# 3        Ariel Matic Top Load Liquid Detergent                  1074
# 16                                    Tata Tea                  1073
# 18               Tenali Double Horse Chana Dal                  1070
# 2      Ariel Matic Front Load Liquid Detergent                  1066
# ...

# %% [markdown]
# - From the above table we can say that:
#     - Maximum unit sold for "Parle Nutricrunch Digestive Cookies" and it's 1166
#     - Minimum unit sold for "Amul Taaza Toned Milk" and it's 1008

# %% [markdown]
# # 4. Visual Representation of Unit wise top 7 Selling Product using Pie Chart

# %%
import  matplotlib.pyplot as plt

# %%
top_7 = Product_unit_sold.head(7)
top_7
# Out:
#                                   Product Name  Estimated Units Sold
# 9          Parle Nutricrunch Digestive Cookies                  1166
# 21                       Wagh Bakri Masala Tea                  1153
# 5             Harpic Bathroom Cleaner - Floral                  1153
# 15       Tata Sampann Moong Dal (Pesara Pappu)                  1126
# 8                Nutri Delite Breakfast Cereal                  1124
# 4                  Cavin's Chocolate Milkshake                  1110
# 7   Nimyle Herbal Anti-Bacterial Floor Cleaner                  1106

# %%
plt.figure(figsize=(5,5))
plt.pie(top_7['Estimated Units Sold'],labels=top_7['Product Name'],autopct='%1.1f%%',shadow=False)
plt.title("Top 7 selling product by Estimated Unit Sold")
plt.axis('equal')
plt.show()

# %% [markdown]
# # 5. Total Revenue by DMart

# %%
Total_Revenue = dataset['Total Order Value'].sum()
print("Total revenue generated by DMart is: ",Total_Revenue)
# Out:
# Total revenue generated by DMart is:  16950082.01

# %% [markdown]
# # 6. Revenue generated by different Marketing and Advertisement

# %%
Revenue_by_Advertisement = dataset.groupby('Marketing/Advertisement')['Total Order Value'].sum().reset_index()
Revenue_by_Advertisement = Revenue_by_Advertisement.sort_values(by='Total Order Value', ascending=False)
Revenue_by_Advertisement
# Out:
#   Marketing/Advertisement  Total Order Value
# 2               Instagram         5754896.75
# 0                Facebook         4219460.18
# 3                   Other         2803531.76
# 1                 Friends         2776784.32
# 4                      TV         1395409.00

# %% [markdown]
# # 7. Visual representation of Total revenue generated by Marketing / Advertisement using Pie Chart

# %%
plt.figure(figsize=(5,5))
plt.pie(Revenue_by_Advertisement['Total Order Value'],labels=Revenue_by_Advertisement['Marketing/Advertisement'],autopct='%1.1f%%',shadow=False)
plt.title("Revenue generated by Marketing/Advertisement")
plt.axis('equal')
plt.show()

# %% [markdown]
# - From the above representation we can conclude that:
#     - Maximum revenue generated from Instagram and it's 34.0%
#     - Minimum revenue generated from TV and it's 8.2%

# %% [markdown]
# # 8. Month wise unit sold in 2023

# %%
data_2023 = dataset[dataset['Year']==2023]
data_2023.head(3)
# Out:
#    Customer ID Product ID   Order ID  Customer Age  Gender  \
# 4        ZOP23      XD230  156544145            22  Female
# 8        RXD22      TK285  746028724            50  Female
# 12       RMX58      PM007   14638526            70    Male
#
#                              Product Name      MRP  Discount Price  Category  \
# 4                          VSR Channa Dal  1249.04          911.80     Local
# 8                Sofit Soya Drink Vanilla    38.02           31.94  Imported
# 12  Ariel Matic Top Load Liquid Detergent  1098.82          977.95   Branded
#
#         State  ... Payment Method Pin Code  Total Order Value  Payment Status  \
# 4     Gujarat  ...         Credit    78304            1011.80            Paid
# 8   Telangana  ...          Debit   118029              31.94            Paid
# 12    Gujarat  ...         Credit   826470             977.95            Paid
#
#    No of Clicks  Year     Month Shipping Charges  Profit Estimated Units Sold
# ...

# %%
Unit_sold_by_month = data_2023.groupby('Month')['Estimated Units Sold'].sum().reset_index()
Unit_sold_by_month = Unit_sold_by_month.sort_values(by='Estimated Units Sold', ascending=False)
Unit_sold_by_month
# Out:
#         Month  Estimated Units Sold
# 9    November                   695
# 2    December                   687
# 10    October                   678
# 8         May                   669
# 0       April                   659
# 7       March                   658
# 1      August                   657
# 5        July                   656
# 11  September                   640
# 3    February                   633
# 4     January                   622
# 6        June                   594

# %% [markdown]
# # 9. Visual Representation of Unit sold in 2023 using Line Graph

# %%
from matplotlib.markers import MarkerStyle

# %%
plt.figure(figsize=(12,5))
plt.plot(Unit_sold_by_month['Month'],Unit_sold_by_month['Estimated Units Sold'],color='orange',marker = 'D',markersize = 5 ,mec = 'r')
plt.xlabel("Month")
plt.ylabel("Estimated Units Sold")
plt.title("Unit Sold in 2023")
plt.show()

# %% [markdown]
# - From the above representation we can conclude that:
#     - In November month maximum(695) unit sold for year 2023
#     - In June month minimum(594) unit sold for year 2023

# %% [markdown]
# # 10. Subscripction wise total order

# %%
Subscription_wise_order = dataset.groupby('Subscription')['Order ID'].count().reset_index()
Subscription_wise_order = Subscription_wise_order.sort_values(by='Order ID',ascending=False)
Subscription_wise_order
# Out:
#    Subscription  Order ID
# 0      Freepass     13956
# 1       Premium      7860
# 2  Premium Plus      3176

# %% [markdown]
# # 11. Visual Representation of Subscripction wise total order using Bar Chart

# %%
plt.figure(figsize=(5,5))
plt.bar(Subscription_wise_order['Subscription'],Subscription_wise_order['Order ID'],color='purple')
plt.xlabel("Subscripction")
plt.ylabel("Total Order")
plt.title("Subscripction wise Total Order")
plt.show()

# %% [markdown]
# - From the above representation we can conclude that:
#     - Maximum total order came from "Freepass" customers
#     - Minimum total order came from "Premium Plus" customer

# %% [markdown]
# # 12. Average Rating of different Product

# %%
Average_Product_Rating = dataset.groupby('Product Name')['Rating'].mean().reset_index()
Average_Product_Rating = Average_Product_Rating.sort_values(by='Rating',ascending=False)
Average_Product_Rating
# Out:
#                                   Product Name    Rating
# 1                        Amul Taaza Toned Milk  3.052429
# 3        Ariel Matic Top Load Liquid Detergent  3.049345
# 17            Tata Tea Chakra Gold Premium Tea  3.045634
# 16                                    Tata Tea  3.042256
# 7   Nimyle Herbal Anti-Bacterial Floor Cleaner  3.038967
# 5             Harpic Bathroom Cleaner - Floral  3.033555
# 4                  Cavin's Chocolate Milkshake  3.024464
# 8                Nutri Delite Breakfast Cereal  3.015952
# 14                      Tata Sampann Chana Dal  3.013201
# 12                    Sofit Soya Drink Vanilla  3.008084
# 0                         Amul Butter Unsalted  3.007424
# 11          Premia Tur Dal Latur (Kandi Pappu)  3.007209
# 10  Pigeon Induction Cooktop Acer Plus: 1800 W  3.003733
# 6                        Kellogg's Corn Flakes  3.000000
# 9          Parle Nutricrunch Digestive Cookies  2.997853
# ...

# %% [markdown]
# - From the above table we can conclude that:
#     - Maximum average rating is for "Amul Taaza Toned Milk" and it's 3.05
#     - Minimum average rating is for "VSR Channa Dal" and it's 2.96
